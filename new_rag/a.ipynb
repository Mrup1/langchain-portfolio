# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- -----------
# absl-py                      2.2.2
# accelerate                   1.8.1
# aiofiles                     24.1.0
# altair                       5.5.0
# annotated-types              0.7.0
# anyio                        4.9.0
# appnope                      0.1.4
# asttokens                    3.0.0
# astunparse                   1.6.3
# attrs                        25.3.0
# blinker                      1.9.0
# cachetools                   5.5.2
# certifi                      2025.4.26
# charset-normalizer           3.4.2
# click                        8.2.1
# comm                         0.2.2
# contourpy                    1.3.2
# cycler                       0.12.1
# debugpy                      1.8.14
# decorator                    5.2.1
# distro                       1.9.0
# executing                    2.2.0
# fastapi                      0.115.13
# ffmpy                        0.6.0
# ...

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- -----------
# absl-py                      2.2.2
# accelerate                   1.8.1
# aiofiles                     24.1.0
# altair                       5.5.0
# annotated-types              0.7.0
# anyio                        4.9.0
# appnope                      0.1.4
# asttokens                    3.0.0
# astunparse                   1.6.3
# attrs                        25.3.0
# blinker                      1.9.0
# cachetools                   5.5.2
# certifi                      2025.4.26
# charset-normalizer           3.4.2
# click                        8.2.1
# comm                         0.2.2
# contourpy                    1.3.2
# cycler                       0.12.1
# debugpy                      1.8.14
# decorator                    5.2.1
# distro                       1.9.0
# executing                    2.2.0
# fastapi                      0.115.13
# ffmpy                        0.6.0
# ...
